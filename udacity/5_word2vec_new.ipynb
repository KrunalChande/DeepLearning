# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      # if a word is not 1 of the 50000 most common word, mark it as unknown
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

# data is just a list of ints where each int is the index to a word
# count is the number of times each word occured 
# dictionary is the mapping of the word to its int index
# reverse dictionary is the mapping of the index to its corresponding word

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
# del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print ("Batch\n", batch)
    print ("labels\n", labels)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
# Batch
#  [3084 3084   12   12    6    6  195  195]
# labels
#  [[  12]
#  [5239]
#  [3084]
#  [   6]
#  [  12]
#  [ 195]
#  [   2]
#  [   6]]
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'as', 'term', 'of', 'a']
# Batch
#  [12 12 12 12  6  6  6  6]
# labels
#  [[ 195]
#  [   6]
#  [5239]
#  [3084]
#  [  12]
#  [3084]
#  [   2]
#  [ 195]]
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'a', 'anarchism', 'originated', 'as', 'originated', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
     tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed, 
                          labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.782984
# Nearest to up: stag, pasteur, pedal, necromancer, jellicoe, cello, snapped, issued,
# Nearest to but: heydrich, defiant, crimean, deference, sedgwick, naci, mislead, boy,
# Nearest to their: elegies, teschen, condensate, lakota, diver, criticism, out, activating,
# Nearest to world: lbs, compensate, sedgwick, cubist, fireman, ribera, paternal, hogeschool,
# Nearest to an: reich, commemorations, wanders, elaine, buddha, guillotine, reinforces, venture,
# Nearest to more: usefulness, positrons, handle, bundestag, lia, religiosity, massachusetts, timing,
# Nearest to american: pentagonal, mardi, vinny, landes, turnpike, pat, overlords, submarine,
# Nearest to some: navigating, westermann, mandaeans, scalar, owner, venous, fewer, qualia,
# Nearest to history: lyre, vanuatu, antiquities, functionaries, demarco, djibouti, attribute, downsizing,
# Nearest to th: masterpieces, pertwee, personified, whig, tamburlaine, schwenkfeld, tate, landau,
# Nearest to is: cladistics, arenas, christina, inmate, mayall, prevented, gallardo, americana,
# Nearest to b: campaign, crust, ninth, superior, warns, dana, provisional, shakyamuni,
# Nearest to called: industrialists, lancashire, city, greeneville, puppy, hx, grozny, judged,
# Nearest to may: kissinger, deeps, keywork, theobald, duane, dread, addiction, bead,
# Nearest to time: boomers, riding, examine, busts, lolita, penitent, eastern, ojibwa,
# Nearest to he: flashy, slowly, saltwater, driver, conic, caucasians, synthesize, bloomington,
# Average loss at step 2000: 4.400105
# Average loss at step 4000: 3.914290
# Average loss at step 6000: 3.811238
# Average loss at step 8000: 3.692443
# Average loss at step 10000: 3.510210
# Nearest to up: ghiorso, thigh, subscribers, pasteur, wyche, stag, remarkably, yeni,
# Nearest to but: that, it, did, still, mack, expensive, mislead, dek,
# Nearest to their: its, his, the, catullus, out, suppressed, doctoral, lok,
# Nearest to world: fireman, telecom, sedgwick, weights, divergence, rattle, fourth, closed,
# Nearest to an: falsity, friction, the, gesellschaft, bayan, reich, vigilante, disappears,
# Nearest to more: pxe, arnaud, most, lou, rehnquist, dubrovnik, noll, poised,
# Nearest to american: pentagonal, hindsight, vinny, flavored, mana, pat, thessaly, appendage,
# Nearest to some: many, these, ahl, its, venous, stockholders, owners, sissy,
# Nearest to history: unstoppable, lyre, antiquities, age, supported, functionaries, tibetan, djibouti,
# Nearest to th: seven, eight, masterpieces, recover, charcoal, pertwee, landau, amd,
# Nearest to is: was, are, has, covers, themed, parlour, be, became,
# Nearest to b: campaign, shakyamuni, superior, ninth, bowstring, mayflower, encyclopedia, ornithology,
# Nearest to called: amusement, lancashire, industrialists, superfamily, grozny, devonport, hx, medea,
# Nearest to may: can, duane, will, could, dubs, top, to, addressee,
# Nearest to time: ojibwa, swings, examine, mayerling, vagueness, soundly, lolita, inflow,
# Nearest to he: it, they, she, who, i, flashy, this, which,
# Average loss at step 12000: 3.604543
# Average loss at step 14000: 3.598352
# Average loss at step 16000: 3.590367
# Average loss at step 18000: 3.584334
# Average loss at step 20000: 3.459204
# Nearest to up: out, thigh, jellicoe, subscribers, ghiorso, mayoral, yeni, lossy,
# Nearest to but: and, however, which, that, though, for, at, reversal,
# Nearest to their: his, its, the, fujian, some, catullus, deflected, lok,
# Nearest to world: fourth, telecom, isothermal, spiritualism, fireman, type, sedgwick, closed,
# Nearest to an: falsity, disappears, rabat, letterboxed, bayan, symbolize, vigilante, mannered,
# Nearest to more: most, pxe, less, arnaud, very, poised, idiopathic, templars,
# Nearest to american: pentagonal, anic, french, daewoo, appendage, landes, netbsd, english,
# Nearest to some: many, these, several, its, this, the, their, any,
# Nearest to history: antiquities, preferences, versions, nicola, area, humiliating, syme, kabbalists,
# Nearest to th: masterpieces, five, pertwee, one, charcoal, recover, landau, tate,
# Nearest to is: was, are, has, were, be, by, covers, had,
# Nearest to b: encyclop, campaign, r, mayflower, ninth, magnetism, opry, seven,
# Nearest to called: amusement, rejoin, grozny, treeless, themed, devonport, industrialists, hx,
# Nearest to may: can, will, would, should, could, must, cannot, might,
# Nearest to time: period, swings, mayerling, rationalists, supermodel, pied, naturalists, soundly,
# Nearest to he: it, she, they, who, this, there, i, publique,
# Average loss at step 22000: 3.500195
# Average loss at step 24000: 3.531684
# Average loss at step 26000: 3.529629
# Average loss at step 28000: 3.532062
# Average loss at step 30000: 3.491092
# Nearest to up: out, thigh, them, jellicoe, subscribers, ghiorso, jawaharlal, lossy,
# Nearest to but: however, and, although, while, that, though, than, residues,
# Nearest to their: its, his, her, the, catullus, some, our, merchandise,
# Nearest to world: fireman, fourth, isothermal, telecom, seu, cretians, authorship, rattle,
# Nearest to an: falsity, bayan, symbolize, guillotine, computing, barriers, letterboxed, mailboxes,
# Nearest to more: less, most, pxe, very, arnaud, templars, bathed, too,
# Nearest to american: french, daewoo, pentagonal, european, german, russian, scottish, mayan,
# Nearest to some: many, these, several, any, all, most, other, their,
# Nearest to history: list, antiquities, preferences, kabbalists, versions, algonquian, chemistry, syme,
# Nearest to th: six, masterpieces, pertwee, nd, km, five, ghibli, landau,
# Nearest to is: was, are, has, ocaml, feininger, became, but, reggaeton,
# Nearest to b: r, c, faerie, d, pastures, ninth, donned, populace,
# Nearest to called: grozny, themed, treeless, zoos, rejoin, written, ubiquitous, tuning,
# Nearest to may: can, would, will, should, could, might, must, cannot,
# Nearest to time: period, rationalists, swings, custody, year, ojibwa, oncology, soundly,
# Nearest to he: she, it, they, who, there, later, i, williams,
# Average loss at step 32000: 3.483497
# Average loss at step 34000: 3.309575
# Average loss at step 36000: 3.338465
# Average loss at step 38000: 3.473714
# Average loss at step 40000: 3.458903
# Nearest to up: out, them, subscribers, back, jawaharlal, jellicoe, issued, lossy,
# Nearest to but: however, while, although, and, though, reversal, than, see,
# Nearest to their: its, his, her, your, some, our, the, catullus,
# Nearest to world: seu, grozny, fireman, isothermal, insisted, cretians, monism, siouxsie,
# Nearest to an: falsity, bayan, guillotine, rabat, symbolize, kampong, sirens, mannered,
# Nearest to more: less, very, most, pxe, highly, faster, rather, increasingly,
# Nearest to american: pentagonal, french, mayan, kilt, independent, daewoo, disenchanted, morphology,
# Nearest to some: many, these, several, any, all, their, most, each,
# Nearest to history: list, humiliating, antiquities, kabbalists, chemistry, preferences, vocally, syme,
# Nearest to th: six, masterpieces, eight, pertwee, km, bc, one, nd,
# Nearest to is: was, are, has, became, be, does, ocaml, were,
# Nearest to b: r, c, d, populace, donned, pastures, loglan, raf,
# Nearest to called: considered, rejoin, treeless, themed, nottingham, hultsfred, known, written,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to time: period, swings, rationalists, soundly, stage, oncology, hengest, custody,
# Nearest to he: she, it, they, who, there, i, bundesl, eventually,
# Average loss at step 42000: 3.424956
# Average loss at step 44000: 3.440866
# Average loss at step 46000: 3.414129
# Average loss at step 48000: 3.376065
# Average loss at step 50000: 3.402843
# Nearest to up: out, them, off, subscribers, down, herold, lossy, back,
# Nearest to but: however, and, although, while, though, than, or, pellucidar,
# Nearest to their: its, his, her, the, your, our, those, some,
# Nearest to world: fireman, isothermal, grozny, seu, insisted, tag, sedgwick, fourth,
# Nearest to an: bayan, falsity, rabat, guillotine, letterboxed, barriers, eicher, symbolize,
# Nearest to more: less, very, most, highly, too, templars, pxe, rather,
# Nearest to american: french, german, english, pentagonal, russian, scottish, european, british,
# Nearest to some: many, several, these, most, all, both, any, various,
# Nearest to history: list, kabbalists, humiliating, vocally, evidently, algonquian, ukrainians, length,
# Nearest to th: eight, six, km, pertwee, masterpieces, bc, four, nd,
# Nearest to is: was, has, are, be, became, ocaml, encoders, does,
# Nearest to b: r, c, d, pastures, delaware, suitor, populace, erhard,
# Nearest to called: considered, known, rigging, treeless, hultsfred, nottingham, fullback, ludo,
# Nearest to may: can, would, could, will, should, might, must, cannot,
# Nearest to time: stage, year, period, swings, rationalists, census, fraternity, oncology,
# Nearest to he: she, it, they, there, who, we, bundesl, but,
# Average loss at step 52000: 3.432303
# Average loss at step 54000: 3.461726
# Average loss at step 56000: 3.458547
# Average loss at step 58000: 3.441145
# Average loss at step 60000: 3.394317
# Nearest to up: out, off, them, down, back, herold, diversified, together,
# Nearest to but: however, and, although, though, while, that, he, they,
# Nearest to their: its, his, her, the, your, our, some, my,
# Nearest to world: seu, insisted, bronx, tag, rattle, cretians, fireman, isothermal,
# Nearest to an: bayan, falsity, disappears, guillotine, letterboxed, mailboxes, interlingua, another,
# Nearest to more: less, most, very, highly, templars, faster, pxe, fewer,
# Nearest to american: french, british, german, pentagonal, russian, scottish, european, italian,
# Nearest to some: many, several, these, any, their, all, certain, most,
# Nearest to history: list, kabbalists, algonquian, humiliating, vocally, margarine, period, evidently,
# Nearest to th: km, bc, nd, six, eight, five, pertwee, seven,
# Nearest to is: was, has, are, if, be, does, became, attachment,
# Nearest to b: c, r, d, k, z, y, x, pastures,
# Nearest to called: considered, used, named, known, rigging, fullback, cryptozoology, hultsfred,
# Nearest to may: can, would, will, could, should, must, might, cannot,
# Nearest to time: period, year, swings, rationalists, stage, oncology, fraternity, wh,
# Nearest to he: she, it, they, there, who, but, williams, originally,
# Average loss at step 62000: 3.411079
# Average loss at step 64000: 3.432622
# Average loss at step 66000: 3.301868
# Average loss at step 68000: 3.404698
# Average loss at step 70000: 3.283724
# Nearest to up: out, off, back, them, down, him, together, subscribers,
# Nearest to but: however, although, while, though, and, than, where, milliseconds,
# Nearest to their: its, his, her, your, our, the, my, those,
# Nearest to world: tag, fireman, bronx, grozny, arbitration, isothermal, fourth, rattle,
# Nearest to an: falsity, bayan, guillotine, eicher, rabat, another, letterboxed, barriers,
# Nearest to more: less, most, very, highly, larger, faster, pxe, templars,
# Nearest to american: british, french, german, russian, pentagonal, english, and, italian,
# Nearest to some: many, several, these, any, most, all, certain, their,
# Nearest to history: list, kabbalists, altruistic, kc, discovery, vocally, algonquian, humiliating,
# Nearest to th: pertwee, bc, nd, masterpieces, rd, twentieth, six, km,
# Nearest to is: was, has, are, became, attachment, represents, although, be,
# Nearest to b: d, c, pulsars, talkative, pauses, batsman, james, chemotherapy,
# Nearest to called: used, considered, named, acclamation, rigging, referred, hultsfred, fullback,
# Nearest to may: can, could, would, must, should, might, will, cannot,
# Nearest to time: period, swings, year, fraternity, manner, rationalists, elven, intension,
# Nearest to he: she, it, they, there, who, we, bundesl, undeniable,
# Average loss at step 72000: 3.406836
# Average loss at step 74000: 3.369073
# Average loss at step 76000: 3.341950
# Average loss at step 78000: 3.406790
# Average loss at step 80000: 3.376851
# Nearest to up: out, off, back, down, him, them, together, jawaharlal,
# Nearest to but: however, although, though, while, than, it, that, immediately,
# Nearest to their: its, his, your, our, her, the, these, those,
# Nearest to world: isothermal, grozny, bronx, insisted, fireman, tag, hartman, spiritualism,
# Nearest to an: bayan, rabat, falsity, disappears, barriers, lubbock, mannered, escorial,
# Nearest to more: less, most, larger, very, highly, pxe, increasingly, longer,
# Nearest to american: british, italian, australian, scottish, russian, french, german, pentagonal,
# Nearest to some: many, several, these, all, any, certain, most, those,
# Nearest to history: list, altruistic, margarine, discovery, vocally, benzoyl, consumption, contradicts,
# Nearest to th: bc, nd, rd, pertwee, km, masterpieces, twentieth, martius,
# Nearest to is: was, has, are, refers, be, holds, topological, seems,
# Nearest to b: d, c, h, pulsars, nou, chemotherapy, batsman, suitor,
# Nearest to called: named, used, considered, known, acclamation, referred, hultsfred, fullback,
# Nearest to may: can, could, would, should, must, might, will, cannot,
# Nearest to time: swings, period, fraternity, year, oncology, elven, before, stone,
# Nearest to he: she, it, they, there, who, we, later, i,
# Average loss at step 82000: 3.252898
# Average loss at step 84000: 3.310428
# Average loss at step 86000: 3.340129
# Average loss at step 88000: 3.352425
# Average loss at step 90000: 3.353247
# Nearest to up: off, out, back, down, them, him, together, jawaharlal,
# Nearest to but: however, although, though, and, than, while, occur, it,
# Nearest to their: its, his, her, your, our, the, my, those,
# Nearest to world: isothermal, bronx, grozny, tag, worst, hartman, seu, folio,
# Nearest to an: falsity, bayan, rabat, longstreet, legitimately, eicher, escorial, lubbock,
# Nearest to more: less, most, highly, very, larger, quite, too, faster,
# Nearest to american: british, english, french, italian, german, australian, russian, european,
# Nearest to some: many, several, any, these, most, certain, various, all,
# Nearest to history: list, altruistic, culture, vocally, hong, moa, margarine, deprived,
# Nearest to th: bc, rd, nd, pertwee, twentieth, six, rigour, eight,
# Nearest to is: was, has, are, although, refers, became, does, holds,
# Nearest to b: d, c, x, h, k, y, erhard, p,
# Nearest to called: named, considered, referred, used, hultsfred, practiced, known, acclamation,
# Nearest to may: can, could, should, would, must, will, might, cannot,
# Nearest to time: period, swings, stone, manner, kind, fraternity, occupants, intension,
# Nearest to he: she, it, they, there, who, we, eventually, this,
# Average loss at step 92000: 3.348437
# Average loss at step 94000: 3.349215
# Average loss at step 96000: 3.277768
# Average loss at step 98000: 3.237339
# Average loss at step 100000: 3.328911
# Nearest to up: off, out, down, back, them, together, him, jawaharlal,
# Nearest to but: however, although, though, and, occur, it, which, reversal,
# Nearest to their: its, his, her, your, the, our, those, theoretician,
# Nearest to world: isothermal, bronx, monism, rebellion, knightly, arbitration, canto, worst,
# Nearest to an: falsity, rabat, mannered, another, guillotine, bayan, pills, lubbock,
# Nearest to more: less, most, highly, larger, very, faster, templars, rather,
# Nearest to american: british, australian, italian, german, russian, scottish, eda, pentagonal,
# Nearest to some: many, several, these, any, various, certain, all, most,
# Nearest to history: list, deprived, altruistic, algonquian, malian, moa, affidavit, collection,
# Nearest to th: bc, rd, nd, twentieth, pertwee, ad, six, martius,
# Nearest to is: was, are, has, remains, be, holds, refers, although,
# Nearest to b: d, c, suitor, j, batsman, zoom, pauses, pickett,
# Nearest to called: named, used, considered, referred, fullback, hultsfred, acclamation, practiced,
# Nearest to may: can, could, should, would, must, might, will, cannot,
# Nearest to time: period, eclipse, year, swings, stone, intension, manner, custody,
# Nearest to he: she, it, they, there, we, who, i, edifices,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index+1) % len(data)
  for i in range(batch_size):
    buffer_list = list(buffer)
    labels[i,0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d ' % (bag_window))
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with bag_window = 1
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %%
batch_size = 128
embedding_size = 128
bag_window = 2
valid_size = 16
valid_window = 100
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64

graph  = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels  = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  embeddings = tf.Variable(tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(tf.truncated_normal([vocabulary_size, embedding_size], stddev=1.0/math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  loss = tf.reduce_mean(tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embed, 1),
                                                  labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))
  
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings/norm
  valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001
with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print ('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels: batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      print ('Avg loss at step %d: %f' % (step, average_loss))
      average_loss = 0
      
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Avg loss at step 0: 7.317988
# Nearest to s: colby, till, rotterdam, diagonal, endocrinology, eno, boasian, inserted,
# Nearest to be: chaotic, seahawks, providence, steyn, masala, manor, extremity, greenfacts,
# Nearest to to: lemming, regulates, barney, monarchists, ruthenian, anguilla, vindicated, reworked,
# Nearest to many: biz, manpower, gigi, banded, importance, rigour, diskette, bju,
# Nearest to no: delimitation, leather, pampas, cleared, cerium, speculated, steer, modesty,
# Nearest to after: frottage, incomparable, apply, piano, chaucer, espoused, philological, bastien,
# Nearest to all: cortez, weiss, clarinet, decidable, ccg, son, instincts, hag,
# Nearest to has: insulated, teutonic, puzo, keynesian, heartfelt, ordaining, vegetation, batavians,
# Nearest to his: honeydew, bir, rna, heidi, antoni, tat, klamath, shrews,
# Nearest to so: silicon, fermium, rod, cts, constants, computerized, sabine, ting,
# Nearest to known: beauharnais, discrimination, therefore, stave, fairmount, pest, amaterasu, sanctioning,
# Nearest to six: birkenau, sightseeing, luminiferous, militar, federalist, slow, laoco, functionalists,
# Nearest to between: dazzling, fein, small, follicle, capitals, tter, recension, fundraising,
# Nearest to often: ttingen, constantin, classless, mouths, asymptotically, biologically, veteran, religious,
# Nearest to other: vecchio, methuen, hebron, steffens, widescreen, gumby, ralf, arbitrarily,
# Nearest to as: missouri, whisper, ty, ec, temperature, intolerant, stride, gpo,
# Avg loss at step 2000: 4.608152
# Avg loss at step 4000: 3.939196
# Avg loss at step 6000: 3.726136
# Avg loss at step 8000: 3.531783
# Avg loss at step 10000: 3.481191
# Nearest to s: unnecessarily, moran, penicillin, kis, anger, anomalies, psychoacoustics, total,
# Nearest to be: have, refer, according, thomas, delegates, patches, was, pursue,
# Nearest to to: would, can, may, could, will, materialistic, withdrawn, nav,
# Nearest to many: some, several, those, all, other, most, various, block,
# Nearest to no: any, an, this, kindling, modesty, flattery, a, thrusts,
# Nearest to after: before, during, explicit, aram, marbles, mystic, exemplified, polisario,
# Nearest to all: many, hardware, lemay, various, cit, virtuoso, dieting, croats,
# Nearest to has: had, have, was, having, is, ve, satyagraha, became,
# Nearest to his: her, their, its, the, invincible, our, klamath, driscoll,
# Nearest to so: formatted, cts, silicon, mitzvot, too, packages, pepin, chechens,
# Nearest to known: used, such, landlocked, referred, progresses, fairmount, famous, regarded,
# Nearest to six: eight, nine, seven, four, five, three, zero, emissaries,
# Nearest to between: with, austere, sized, ringworld, in, sorbonne, sassanians, donor,
# Nearest to often: still, also, licensee, burdened, treated, castro, combinatory, usually,
# Nearest to other: different, reggaeton, many, these, several, sonorants, more, some,
# Nearest to as: crippling, othon, vit, rowe, redactor, nicotine, elton, encompassed,
# Avg loss at step 12000: 3.494513
# Avg loss at step 14000: 3.440736
# Avg loss at step 16000: 3.434131
# Avg loss at step 18000: 3.402036
# Avg loss at step 20000: 3.215217
# Nearest to s: his, my, kathleen, lindbergh, isbn, whose, moselle, krona,
# Nearest to be: refer, have, roanoke, being, occur, wto, geologically, get,
# Nearest to to: will, must, could, would, may, thunderbirds, warhead, displeasure,
# Nearest to many: some, several, various, these, most, those, all, such,
# Nearest to no: any, still, hinton, kindling, modesty, penetrated, nox, steer,
# Nearest to after: before, during, coincidences, when, approx, following, despite, declares,
# Nearest to all: several, many, bagoas, both, some, these, landless, sow,
# Nearest to has: had, have, having, is, ve, was, annuity, contains,
# Nearest to his: their, her, its, s, the, yeats, my, invincible,
# Nearest to so: unconstitutional, inherited, believe, formatted, mathilde, copland, dogg, hence,
# Nearest to known: used, referred, regarded, called, seen, considered, cavendish, such,
# Nearest to six: seven, five, four, three, eight, zero, nine, chopped,
# Nearest to between: against, through, with, austere, in, balfour, privates, within,
# Nearest to often: usually, still, sometimes, also, generally, now, which, pannonia,
# Nearest to other: different, these, various, sonorants, certain, reintroduced, expenditure, statism,
# Nearest to as: nicotine, macao, kingfishers, nanny, udo, almohad, titanic, finalised,
# Avg loss at step 22000: 3.367146
# Avg loss at step 24000: 3.279442
# Avg loss at step 26000: 3.256573
# Avg loss at step 28000: 3.284771
# Avg loss at step 30000: 3.227045
# Nearest to s: penicillin, his, drenthe, vanessa, ethnological, mustafa, custis, touchdowns,
# Nearest to be: refer, become, remain, being, get, roanoke, develop, occur,
# Nearest to to: would, must, will, might, drogheda, may, could, can,
# Nearest to many: several, some, various, most, all, these, different, certain,
# Nearest to no: any, little, hinton, utero, an, modesty, amplifies, falsetto,
# Nearest to after: before, during, despite, from, when, since, following, through,
# Nearest to all: some, many, both, various, any, distinguishing, several, platonic,
# Nearest to has: had, have, having, is, was, gives, shura, contains,
# Nearest to his: her, their, its, my, the, s, pearce, yeats,
# Nearest to so: unconstitutional, adnan, debian, detractors, duress, sometimes, lawyers, basalt,
# Nearest to known: referred, regarded, used, seen, well, such, called, described,
# Nearest to six: five, eight, four, nine, seven, three, zero, two,
# Nearest to between: with, within, into, against, through, under, mtp, privates,
# Nearest to often: sometimes, usually, still, commonly, also, frequently, generally, widely,
# Nearest to other: different, various, those, these, several, bethlen, all, both,
# Nearest to as: phrasing, invasions, nicotine, spr, macao, supporting, nanny, became,
# Avg loss at step 32000: 3.011790
# Avg loss at step 34000: 3.198029
# Avg loss at step 36000: 3.201053
# Avg loss at step 38000: 3.163655
# Avg loss at step 40000: 3.169081
# Nearest to s: madeleine, marc, surrey, ligands, and, palestrina, keystrokes, niccolo,
# Nearest to be: being, refer, remain, been, lead, produce, have, provide,
# Nearest to to: would, will, must, could, might, cannot, may, can,
# Nearest to many: several, some, various, all, both, ten, certain, these,
# Nearest to no: modesty, little, an, any, ods, sextus, hinton, amplifies,
# Nearest to after: before, during, when, despite, through, since, following, later,
# Nearest to all: every, many, various, these, any, several, some, manipulation,
# Nearest to has: had, have, having, is, was, contains, includes, can,
# Nearest to his: her, their, its, my, your, our, the, klamath,
# Nearest to so: too, detractors, pn, unconstitutional, gabbro, inherited, hartree, basalt,
# Nearest to known: seen, referred, regarded, used, defined, described, considered, viewed,
# Nearest to six: eight, seven, five, four, three, zero, nine, two,
# Nearest to between: within, with, among, quantifier, through, aurangabad, habitually, actinides,
# Nearest to often: usually, sometimes, commonly, frequently, generally, still, bazille, widely,
# Nearest to other: various, these, different, more, lambeau, ah, rather, several,
# Nearest to as: macao, messier, preston, pneumatic, hopwood, zap, when, exhibits,
# Avg loss at step 42000: 3.214249
# Avg loss at step 44000: 3.145131
# Avg loss at step 46000: 3.135963
# Avg loss at step 48000: 3.061746
# Avg loss at step 50000: 3.058958
# Nearest to s: whose, isbn, his, penicillin, preeminence, ghanaian, bipartisan, poised,
# Nearest to be: being, refer, provide, produce, take, make, vary, remain,
# Nearest to to: could, must, can, will, should, would, may, might,
# Nearest to many: some, several, various, all, certain, number, numerous, both,
# Nearest to no: little, any, hinton, another, falsetto, modesty, lesions, utero,
# Nearest to after: before, when, during, following, despite, without, afterwards, for,
# Nearest to all: several, many, various, some, every, these, consecutive, both,
# Nearest to has: had, have, having, is, contains, includes, was, gives,
# Nearest to his: her, their, its, our, my, the, your, s,
# Nearest to so: too, thus, unconstitutional, analyzed, believe, inaugural, gabbro, later,
# Nearest to known: regarded, seen, referred, used, defined, described, such, possible,
# Nearest to six: seven, five, eight, four, nine, three, zero, alp,
# Nearest to between: within, with, among, aurangabad, henning, habitually, quantifier, thus,
# Nearest to often: usually, sometimes, generally, frequently, commonly, still, widely, also,
# Nearest to other: individual, various, different, smaller, these, multiple, rather, larger,
# Nearest to as: preston, nanny, garland, nicotine, titanic, spr, udo, rowe,
# Avg loss at step 52000: 3.098224
# Avg loss at step 54000: 3.092902
# Avg loss at step 56000: 2.917696
# Avg loss at step 58000: 3.029057
# Avg loss at step 60000: 3.046797
# Nearest to s: his, whose, my, drenthe, cir, basileus, mustafa, cosworth,
# Nearest to be: being, remain, refer, produce, occur, lead, have, cause,
# Nearest to to: cannot, will, could, might, must, would, should, may,
# Nearest to many: some, several, various, numerous, certain, most, all, few,
# Nearest to no: another, any, little, a, inconspicuous, lesions, hinton, falsetto,
# Nearest to after: before, during, since, following, when, despite, afterwards, without,
# Nearest to all: various, several, some, these, certain, many, consecutive, seperate,
# Nearest to has: had, have, having, is, contains, includes, gives, requires,
# Nearest to his: her, their, its, our, my, s, your, the,
# Nearest to so: sometimes, too, note, snowball, lawyers, rind, believe, unconstitutional,
# Nearest to known: regarded, defined, seen, referred, described, used, classified, considered,
# Nearest to six: seven, five, eight, four, three, zero, nine, two,
# Nearest to between: with, through, within, thus, across, aurangabad, among, quantifier,
# Nearest to often: usually, sometimes, frequently, generally, commonly, still, widely, typically,
# Nearest to other: various, these, rather, different, others, several, smaller, certain,
# Nearest to as: curlers, repetitive, nicotine, macao, phrasing, messier, halld, how,
# Avg loss at step 62000: 3.009655
# Avg loss at step 64000: 2.923520
# Avg loss at step 66000: 2.934262
# Avg loss at step 68000: 2.945520
# Avg loss at step 70000: 3.007067
# Nearest to s: his, whose, isbn, drenthe, arf, penicillin, materiality, vanessa,
# Nearest to be: remain, being, cause, refer, produce, occur, lead, become,
# Nearest to to: will, must, cannot, might, can, could, would, should,
# Nearest to many: some, several, various, numerous, all, these, certain, most,
# Nearest to no: another, a, nothing, oe, decatur, every, disturbs, para,
# Nearest to after: before, during, following, despite, when, afterwards, since, throughout,
# Nearest to all: several, many, various, some, certain, every, consecutive, numerous,
# Nearest to has: had, have, having, contains, includes, is, was, gives,
# Nearest to his: her, their, its, your, my, the, s, our,
# Nearest to so: believe, snowball, gabbro, indicate, gringo, too, inaugural, aosta,
# Nearest to known: regarded, referred, defined, seen, described, used, available, classified,
# Nearest to six: seven, five, three, eight, zero, four, two, wealthiest,
# Nearest to between: with, among, within, quantifier, across, through, pro, deltas,
# Nearest to often: sometimes, frequently, generally, commonly, usually, still, currently, typically,
# Nearest to other: various, trumpets, smaller, fewer, older, rather, different, keepers,
# Nearest to as: preston, nanny, udo, internationally, spr, staffed, exhibits, zap,
# Avg loss at step 72000: 2.939583
# Avg loss at step 74000: 2.866475
# Avg loss at step 76000: 2.988215
# Avg loss at step 78000: 3.005591
# Avg loss at step 80000: 2.850445
# Nearest to s: his, whose, smallholders, our, ethnological, isbn, arf, designates,
# Nearest to be: refer, remain, create, occur, become, being, produce, provide,
# Nearest to to: might, will, may, would, should, can, cannot, must,
# Nearest to many: some, several, various, numerous, all, most, multiple, certain,
# Nearest to no: any, little, nothing, a, only, oe, hinton, curls,
# Nearest to after: before, during, afterwards, following, when, since, despite, coincidences,
# Nearest to all: many, various, some, several, knoxville, both, every, numerous,
# Nearest to has: had, have, having, contains, is, includes, provides, gives,
# Nearest to his: her, their, its, your, my, our, the, s,
# Nearest to so: too, gabbro, unconstitutional, believe, festivities, before, duress, sometimes,
# Nearest to known: referred, regarded, described, seen, used, recognized, defined, opposed,
# Nearest to six: seven, four, eight, five, three, zero, nine, two,
# Nearest to between: with, deltas, within, across, reverses, among, therefore, privates,
# Nearest to often: sometimes, usually, frequently, generally, commonly, typically, widely, still,
# Nearest to other: various, fewer, these, quotas, rather, ah, reassignment, trumpets,
# Nearest to as: nicotine, macao, curlers, spr, garland, udo, titanic, gideon,
# Avg loss at step 82000: 2.940029
# Avg loss at step 84000: 2.903760
# Avg loss at step 86000: 2.918936
# Avg loss at step 88000: 2.940751
# Avg loss at step 90000: 2.837565
# Nearest to s: isbn, arf, acharya, penicillin, materiality, monopolize, ori, stills,
# Nearest to be: refer, being, occur, remain, represent, create, been, lead,
# Nearest to to: must, will, cannot, might, should, may, can, would,
# Nearest to many: some, numerous, various, several, both, all, certain, most,
# Nearest to no: little, nothing, any, another, alexandrians, lvaro, always, oe,
# Nearest to after: before, during, afterwards, without, despite, until, following, since,
# Nearest to all: many, various, both, certain, some, numerous, every, any,
# Nearest to has: had, have, contains, having, is, provides, requires, includes,
# Nearest to his: her, their, its, your, my, our, the, yeats,
# Nearest to so: believe, gabbro, snowball, too, sometimes, fact, waive, once,
# Nearest to known: regarded, referred, recognized, defined, described, seen, viewed, used,
# Nearest to six: seven, five, four, three, eight, nine, zero, two,
# Nearest to between: with, therefore, across, quantifier, within, aurangabad, laodicea, into,
# Nearest to often: usually, generally, frequently, sometimes, commonly, typically, still, normally,
# Nearest to other: various, both, quotas, sonorants, fewer, others, different, muslim,
# Nearest to as: udo, macao, nicotine, zap, phrasing, beyond, spr, prsc,
# Avg loss at step 92000: 2.897600
# Avg loss at step 94000: 2.891285
# Avg loss at step 96000: 2.714235
# Avg loss at step 98000: 2.458251
# Avg loss at step 100000: 2.709641
# Nearest to s: his, isbn, ethnological, lieder, mustafa, whose, our, vanessa,
# Nearest to be: remain, being, occur, refer, create, lead, roanoke, survive,
# Nearest to to: will, must, would, cannot, might, can, should, may,
# Nearest to many: some, several, various, numerous, both, all, most, hundreds,
# Nearest to no: little, nothing, always, hinton, affleck, inconspicuous, any, improvisations,
# Nearest to after: before, afterwards, without, despite, following, for, upon, thereafter,
# Nearest to all: many, various, every, some, certain, both, several, always,
# Nearest to has: had, have, having, contains, includes, provides, is, gives,
# Nearest to his: their, her, its, our, your, s, my, whose,
# Nearest to so: later, too, sometimes, believe, mcmanus, gabbro, before, waive,
# Nearest to known: regarded, defined, referred, seen, recognized, described, cited, used,
# Nearest to six: seven, five, four, eight, three, zero, nine, two,
# Nearest to between: with, within, across, in, courageous, among, surrounding, therefore,
# Nearest to often: sometimes, usually, generally, frequently, typically, commonly, still, also,
# Nearest to other: others, various, individual, both, rather, quotas, shortening, these,
# Nearest to as: spr, nanny, slates, titanic, udo, zap, nicotine, phrasing,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
